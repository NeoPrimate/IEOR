# %%
from scipy.stats import t, norm
import numpy as np

xbar = 10
s = 5
n = 1000

conf = 0.90

alpha = 1 - conf
p = 1 - alpha / 2
crit = t.ppf(p, df=n-1)
se = s / (np.sqrt(n))

print(f"Alpha: {alpha:.2f}")
print(f"Cumulative Probability: {p:.2f}")
print(f"Critical Value: {crit:.2f}")
print(f"Standard Error: {se:.2f}")

lower = xbar - crit * se
upper = xbar + crit * se

print(f"Confidence Interval: [{lower:.2f}, {upper:.2f}]")
# Out:
# Cumulative Probability: 0.95
# Critical Value: 1.65
# Standard Error: 0.16
# Confidence Interval: [9.74, 10.26]

# %%
from scipy.stats import t
import numpy as np

xbar = 10
s = 5
n = 1000

conf = 0.99

p = 1 - ((1 - conf) / 2)
crit = t.ppf(p, df=n-1)

se_pred = s * np.sqrt(1 + (1 / n))

print(f"Standard Error Prediction: {se_pred:.2f}")

lower = xbar - crit * se_pred
upper = xbar + crit * se_pred

print(f"Prediction Interval: [{lower:.2f}, {upper:.2f}]")
# Out:
# Prediction Interval: [-2.91, 22.91]

# %%
import numpy as np
from scipy.stats import norm, t

# %%
n = 64

xbar = 52
sigma = 8

conf = 0.95

p = 1 - ((1 - conf) / 2)

crit = norm.ppf(p)

lo = xbar - crit * sigma / np.sqrt(n - 1)
hi = xbar + crit * sigma / np.sqrt(n - 1)

print(lo, hi)
# Out:
# 50.024541987910006 53.975458012089994

# %%
n = 15
xbar = 100
s = 12
conf = 0.95
df = n - 1

p = 1 - ((1 - conf) / 2)

crit = t.ppf(p, df=df)

lo = xbar - crit * s / np.sqrt(n - 1)
hi = xbar + crit * s / np.sqrt(n - 1)

print(lo, hi)
# Out:
# 93.12137975379822 106.87862024620178

# %%
Out of 200 users, 
46 convert
Build a 95% CI for the true conversion rate. 
Use the standard (Wald) formula: SE = √(p̂(1−p̂)/n), 
z = 1.96. 
Watch that the SE formula is different from the mean case.
